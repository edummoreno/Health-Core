# %% [markdown]
# # 🏥 Health Core API - Estudos Iniciais
#
# ## 1. Importação e Configuração
# Aqui nós importamos a biblioteca necessária e criamos a "caixa" principal da nossa aplicação.
#
# * **from / import**: Comandos de importação.
# * **FastAPI**: Classe (o molde) usada para criar a API.
# * **Fastapi**: biblioteca que você instalou com `pip install fastapi`.

# %%
from fastapi import FastAPI

# Cria um objeto da classe FastAPI
app = FastAPI(title="Health Core API")

# app -> variavel
# FastAPI(...) -> chamada do construtor, que cria a API
# title="..." -> argumento (um valor passado para a classe).

# %% [markdown]
# ## 2. Criando a Primeira Rota (Path Operation)
#
# Aqui usamos um **Decorator** (`@app.get`) para dizer ao Python: *"Quando alguém acessar o endereço principal, execute a função abaixo"*.
#
# * **@app.get("/")**: Cria uma rota do tipo GET no endereço raiz (`http://127.0.0.1:8000/`).
# * **def**: Define a função.
# * **return**: Devolve um **Dicionário** (JSON) para quem acessou o site.

# %%
# Isso é um decorator.
@app.get("/")
def read_root():
    # Retorna um dicionário Python.
    return {"status": "ok", "message": "Health Core API Online"}

    # return -> palavra-chave que devolve o valor da função
    # {...} -> dicionário (estrutura de dados)
    # É isso que o usuário verá ao acessar a API.

# %% [markdown]
# ## 3. Como Rodar o Servidor?
#
# O comando abaixo deve ser rodado no **TERMINAL** do VS Code (não em uma célula de código), pois ele inicia um processo contínuo.
#
# ```bash
# uvicorn main:app --reload
# ```
#
# * **main**: Nome do arquivo (`main.py`). Se estivesse em um arquivo .py.
# * **app**: Nome da variável que criamos lá em cima.
# * **--reload**: Reinicia o servidor se mudarmos o código.
#
# ### Saída Esperada (Output):
#
# ```text
# INFO: Uvicorn running on [http://127.0.0.1:8000](http://127.0.0.1:8000)
# INFO: Started reloader process
# INFO: Application startup complete.
# ```
#
# **Significado:**
# O servidor está rodando e disponível em: http://127.0.0.1:8000
